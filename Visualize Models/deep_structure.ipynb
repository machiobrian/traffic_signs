# %%
#basic ANN

from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# 2022-07-26 00:23:23.455972: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='Vis_1.png',show_shapes=True, show_layer_names=True)

# %%
from keras import models  
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Activation ,Dropout
from keras import layers 

model = Sequential()
model.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(128,(4,4),input_shape=(32,32,3),activation='relu',padding='same'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.35))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

#plot_model(model, to_file='Vis_1.png',show_shapes=True, show_layer_names=True)
import visualkeras
from PIL import ImageFont
font = ImageFont.truetype("arial.ttf",14)
visualkeras.layered_view(model, legend=True, font=font, draw_volume=False)
# Out:
# <PIL.Image.Image image mode=RGBA size=503x164>
